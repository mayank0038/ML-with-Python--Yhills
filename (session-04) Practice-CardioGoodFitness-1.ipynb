# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/drive/MyDrive/Datasets-main/CardioGoodFitness-1.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 110   TM498   26    Male         16        Single      4        3   51165
# 71    TM195   38    Male         16     Partnered      3        3   56850
# 126   TM498   34    Male         16     Partnered      3        4   59124
# 107   TM498   25    Male         14        Single      4        3   48891
# 147   TM798   24    Male         18     Partnered      4        5   57271
# 3     TM195   19    Male         12        Single      3        3   32973
# 93    TM498   23    Male         16     Partnered      3        3   45480
# 148   TM798   24  Female         16        Single      5        5   52291
# 67    TM195   37  Female         16     Partnered      3        3   37521
# 171   TM798   33  Female         18     Partnered      4        5   95866
#
#      Miles
# 110    106
# 71      75
# 126     85
# 107    127
# 147     80
# 3       85
# 93      64
# 148    200
# 67      85
# 171    200

# %%
df.shape
# Out:
# (180, 9)

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# in the above table
# * count means total items in the table
# * unique means in the particular column how many unique values
# * top means how many times a particular item is repeated in the column
# * freq means the number of particular repeated item in the column
# and rest are normal, we don't need to describe.

# %%
sns.countplot(x='Product', data=df,palette='Paired')
plt.show()

# %%
df['Product'].nunique()
# Out:
# 3

# %%
# isse ekdum normal wala pie chart generate hota hai
import plotly.express as px
fig=px.pie(df,names='Product')
# set the title
fig.update_layout(title='Titanic passenger class distribution.')
fig.show()

# vahi hai jitne kam distinct value ke column ka pie chart banaeinge utna achha chart banega.
# aur ye baat har ek plot per lagu hoti hai.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ismein pie chart ke ek piece ko alag krke dikhaya jata hai. jo piece alag hota hai usi ka color change hoga bas.
# ultimately ismein hum pie chart ke color ko change kr skte hain.
import plotly.graph_objects as go
explode_effect=[0.1, 0.1, 0.1]
# explode ka matlab piechart ke pieces ko alag alag karna.
# aur jo explode variable mein values di hain unhe change krke ham pieces ke bich ke gap ko kam-jada bhi kar sakte hain.
# most important explode ki value sirf or sirf 0 aur 1 ke bich hi honi chahiye (either int or float but b/w 0 and 1).
custom_colors=['yellow']
# baki ke colors same hi rahenge jo pie chart mein bydefault aaye hain.
# 'custom_colors' variable mein agar 1 value bhi dete hain (matlab 1 color dete hain) to bhi koi dikkat nahi hai.
fig=go.Figure(go.Pie(
    labels=df['Gender'],
# labels variable mein apni table ka jo column name denge vo hi pie chart ke rup mein show hoga.
# jese isse phle 'Products' ko labels mein diya tha to products ko pie chart ke rup mein show kr diya.
    pull=explode_effect,
    marker=dict(colors=custom_colors)))

#set the title
fig.update_layout(title='Titanic passenger class distribution.')

# show the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# why error? I am saying such because sometimes when plotly is not upgraded then we'll face error. To upgrage this,
# 'pip install plotly --upgrade' is used in anaconda prompt.

# %%
import plotly.graph_objects as go
explode_effect=[0.1, 0.1, 0]
custom_colors=['red','green']
fig=go.Figure(go.Pie(
    labels=df['Product'],
    pull=explode_effect,
    marker=dict(colors=custom_colors)
))

# set the title
fig.update_layout(title='Titanic passenger class distribution.')

# show the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig=px.box(df,x='Product', y='Age')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
